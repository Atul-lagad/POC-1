# %%
class car:
  def __init__(self):
    self.wheel=4
    self.axel=2
    self.airbag='Yes'
  #common fun to print info of classes
  def showinfo(self,dict):

    for x,y in dict.items():
      print(x,":",y)



class M01(car):
  def __init__(self):
    self.Model_Type="Manual"
    self.Engine_type="Gasoline"
    #car info is stored in a dict
    dict_M01={'Name':"Volkswagen Golf GTI",'Model_Type':self.Model_Type ,'Engine_type':self.Engine_type,
              'BHP':'189.3 Bhp' , 'colour':'black' , 'fuel':'petrol'}
    super().showinfo(dict_M01)
    dict_M011={'Name':'Lexus ES Hybrid','Model_Type':self.Model_Type ,'Engine_type':self.Engine_type,
            'BHP':'125.3 Bhp' , 'Brake Front/Rear':'Disc' , 'No. of Cylinders':'In line - 4 cylinder' ,'Colour':"white"}

    starprint()
    ip=input('**** Want to see another one ****(yes,no)')
    if 'yes'==ip:
      starprint()
      super().showinfo(dict_M011)
    else:
      starprint()
      print('Thanks You For Online Visit ')

class M02(car):
  def __init__(self):
    self.Model_Type="Automatic"
    self.Engine_type="Gasoline"
    #car info is stored in a dict
    dict_M02={'Name':"Hyundai i20",'Model_Type':self.Model_Type ,'Engine_type':self.Engine_type,
              'seats':'5' , 'colour':'red' , 'Brake':'Disc'}
    super().showinfo(dict_M02)
    dict_M021={'Name':'Lexus ES Hybrid','Model_Type':self.Model_Type ,'Engine_type':self.Engine_type,
            'BHP':'125.3 Bhp' , 'Brake Front/Rear':'Disc' , 'No. of Cylinders':'In line - 4 cylinder' ,'Colour':"white"}

    starprint()
    ip=input('**** Want to see another one ****(yes,no)')
    if 'yes'==ip:
      starprint()
      super().showinfo(dict_M021)
    else:
      starprint()
      print('Thanks You For Online Visit ')

class M03(car):
  def __init__(self):
    self.Model_Type="Automatic"
    self.Engine_type="Electric"
    #car info is stored in a dict
    dict_M03={'Name':"Tata Nexon AMT",'Model_Type':self.Model_Type ,'Engine_type':self.Engine_type,
              'BHP':'118.5 Bhp' , 'colour':'rose red' , 'No. of cylinder':'3'}
    super().showinfo(dict_M03)
    dict_M031={'Name':'Lexus ES Hybrid','Model_Type':self.Model_Type ,'Engine_type':self.Engine_type,
            'BHP':'125.3 Bhp' , 'Brake Front/Rear':'Disc' , 'No. of Cylinders':'In line - 4 cylinder' ,'Colour':"white"}

    starprint()
    ip=input('**** Want to see another one ****(yes,no)')
    if 'yes'==ip:
      starprint()
      super().showinfo(dict_M031)
    else:
      starprint()
      print('Thanks You For Online Visit ')



class M04(car):
  def __init__(self):
    self.Model_Type="Automatic"
    self.Engine_type="Gasoline and Electric"
    #car info is stored in a dict
    dict_M04={'Name':"Toyota Camry Hybrid",'Model_Type':self.Model_Type ,'Engine_type':self.Engine_type,
              'BHP':'189.3 Bhp' , 'Brake Front/Rear':'Disc' , 'No. of Cylinders':'In line - 4 cylinder'}
    super().showinfo(dict_M04)
    dict_M041={'Name':'Lexus ES Hybrid','Model_Type':self.Model_Type ,'Engine_type':self.Engine_type,
            'BHP':'125.3 Bhp' , 'Brake Front/Rear':'Disc' , 'No. of Cylinders':'In line - 4 cylinder' ,'Colour':"white"}

    starprint()
    ip=input('**** Want to see another one ****(yes,no)')
    try:
      if 'yes'==ip:
        starprint()
        super().showinfo(dict_M041)
    except:
      print("please valid input")
    else:
      starprint()
      print('Thanks You For Online Visit ')

def starprint():
  for i in range(0,100):
    print("*",end="")
  print("")

# %%
print("Welcome to Automotive Car")
starprint()
try:
  model_type=int(input("which type of Car model you want : 1) Manual ,2) Automatic :"))
  engine_type=int(input("which type of Car engine you want : 1) Gasoline ,2) Electric ,3) Gasoline and Electric  :"))
  starprint()
except:
  print("please enter Digits which are shown near the option")
else:
  if model_type==1 and engine_type==1:
    print("In this segment Manual and  Gasoline we have following options")
    obj=M01()
  elif model_type==2 and engine_type==1:
    print("In this segment Automatic and  Gasoline we have following options")
    obj=M02()
  elif model_type==2 and engine_type==2:
    print("In this segment Automatic and  Electric we have following options")
    obj=M03()
  elif model_type==2 and engine_type==3:
    print("In this segment Automatic and   Gasoline+Electric we have following options")
    obj=M04()
  else:
    print("please  enter valid inputs")
# Out:
# Welcome to Automotive Car
# ****************************************************************************************************
# which type of Car model you want : 1) Manual ,2) Automatic :2
# which type of Car engine you want : 1) Gasoline ,2) Electric ,3) Gasoline and Electric  :3
# ****************************************************************************************************
# In this segment Automatic and   Gasoline+Electric we have following options
# Name : Toyota Camry Hybrid
# Model_Type : Automatic
# Engine_type : Gasoline and Electric
# BHP : 189.3 Bhp
# Brake Front/Rear : Disc
# No. of Cylinders : In line - 4 cylinder
# ****************************************************************************************************
# **** Want to see another one ****(yes,no)yes
# ****************************************************************************************************
# Name : Lexus ES Hybrid
# Model_Type : Automatic
# Engine_type : Gasoline and Electric
# ...
